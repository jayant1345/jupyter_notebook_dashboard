# %% [markdown]
# # Sample Hello Notebook
# This is a test notebook for the dashboard.

# %%
import time
print('Starting sample notebook...')

# %%
for i in range(1, 6):
    print(f'Step {i}/5 — processing...')
    time.sleep(1)

# %%
print('Done! Notebook executed successfully.')
